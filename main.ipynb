# %%
import pandas as pd

df = pd.read_json('farmers-protest-tweets-2021-03-5.json', lines = True)
df.head()
# Out:
#                                                  url  \
# 0  https://twitter.com/ShashiRajbhar6/status/1376...
# 1  https://twitter.com/kaursuk06272818/status/137...
# 2  https://twitter.com/kaursuk06272818/status/137...
# 3  https://twitter.com/SukhdevSingh_/status/13767...
# 4  https://twitter.com/Davidmu66668113/status/137...
#
#                        date  \
# 0 2021-03-30 03:33:46+00:00
# 1 2021-03-30 03:33:23+00:00
# 2 2021-03-30 03:31:00+00:00
# 3 2021-03-30 03:30:45+00:00
# 4 2021-03-30 03:30:30+00:00
#
#                                              content  \
# 0                       Support 👇\n\n#FarmersProtest
# 1  Supporting farmers means supporting our countr...
# 2  Support farmers if you are related to food #St...
# 3  #StopHateAgainstFarmers support #FarmersProtes...
# 4  You hate farmers I hate you, \nif you love the...
#
#                                      renderedContent                   id  \
# ...

# %%
def main():
   most_retweeted_tweets()
   #most_active_users()

def most_retweeted_tweets():
    tweets = df.loc[df['retweetCount'].nlargest(n=10)]
    print(tweets)

def most_active_users():
    df['user'] = df['user'].map(lambda col: col['username'], na_action='ignore')
    print(df['user'].value_counts()[:10])
    

def days_with_the_most_tweets():
    pass

def most_used_hashtags():
    pass

# %%
main()
# Out:
#                                                       url  \
# 315547  https://twitter.com/kairanaexperess/status/135...
# 103957  https://twitter.com/jot__b/status/136330704530...
# 67694   https://twitter.com/NeelKam71287835/status/136...
# 35921   https://twitter.com/Dal321/status/137176270835...
# 26972   https://twitter.com/SoulRural/status/137295864...
# 23251   https://twitter.com/Parmind74776100/status/137...
# 20132   https://twitter.com/moieeez/status/13739271629...
# 18744   https://twitter.com/indianproud12/status/13741...
# 17368   https://twitter.com/psd4haryana/status/1374371...
# 15677   https://twitter.com/AntardeepK/status/13746079...
#
#                             date  \
# 315547 2021-02-03 19:09:00+00:00
# 103957 2021-02-21 01:58:23+00:00
# 67694  2021-03-04 05:03:38+00:00
# 35921  2021-03-16 09:58:10+00:00
# 26972  2021-03-19 17:10:23+00:00
# 23251  2021-03-21 02:56:57+00:00
# 20132  2021-03-22 09:18:56+00:00
# 18744  2021-03-23 02:48:36+00:00
# ...
